# %%
import pandas as pd
df = pd.read_excel (r'C:\Users\jessi\Desktop\ANZ synthesised transaction dataset.xlsx')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12043 entries, 0 to 12042
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   status             12043 non-null  object
#  1   card_present_flag  7717 non-null   float64
#  2   bpay_biller_code   885 non-null    object
#  3   account            12043 non-null  object
#  4   currency           12043 non-null  object
#  5   long               12043 non-null  float64
#  6   lat                12043 non-null  float64
#  7   txn_description    12043 non-null  object
#  8   merchant_id        7717 non-null   object
#  9   merchant_code      883 non-null    float64
#  10  first_name         12043 non-null  object
#  11  balance            12043 non-null  float64
#  12  date               12043 non-null  datetime64[ns]
#  13  gender             12043 non-null  object
#  14  age                12043 non-null  int64
# ...

# %%
df.describe()
# Out:
#        card_present_flag  merchant_code        balance           age  \
# count        7717.000000          883.0   12043.000000  12043.000000
# mean            0.802644            0.0   14704.195553     30.582330
# std             0.398029            0.0   31503.722652     10.046343
# min             0.000000            0.0       0.240000     18.000000
# 25%             1.000000            0.0    3158.585000     22.000000
# 50%             1.000000            0.0    6432.010000     28.000000
# 75%             1.000000            0.0   12465.945000     38.000000
# max             1.000000            0.0  267128.520000     78.000000
#
#              amount  merchant_long  merchant_lat
# count  12043.000000    7717.000000   7717.000000
# mean     187.933588     143.433277    -32.752651
# std      592.599934      12.090074      5.282423
# min        0.100000     113.830000    -43.310000
# 25%       16.000000     144.680000    -37.710000
# ...

# %%
df['txn_description'].unique()
# Out:
# array(['POS', 'SALES-POS', 'PAYMENT', 'INTER BANK', 'PAY/SALARY',
#        'PHONE BANK'], dtype=object)

# %% [raw]
# # age = df.groupby('age').size()
# # mean = df.groupby('age').mean()
# # print(age,mean)

# %%
adf=df[(df['customer_id'] == 'CUS-2031327464')]
adf[['txn_description','balance','amount']].head(50)
# df.loc[df['customer_id'] == 'CUS-1005756958']
# get_paid = df[df['txn_description'] == 'PAYMENT']
# get_paid.groupby(['date']).size().head(15)
# Out:
#      txn_description   balance   amount
# 9         INTER BANK    466.58    21.00
# 52               POS    454.94    11.64
# 55         SALES-POS    440.66    14.28
# 78         SALES-POS    429.20    11.46
# 383          PAYMENT    388.20    41.00
# 657          PAYMENT    363.20    25.00
# 673          PAYMENT    174.20   189.00
# 725       PAY/SALARY   2454.56  2280.36
# 884       INTER BANK   2433.56    21.00
# 1114             POS   2382.25    51.31
# 1178       SALES-POS   2333.20    49.05
# 1187       SALES-POS   2313.11    20.09
# 1192       SALES-POS   2302.35    10.76
# 1214       SALES-POS   2284.38    17.97
# 1254         PAYMENT   2243.38    41.00
# 1519         PAYMENT   2158.38    85.00
# 1553         PAYMENT   2133.38    25.00
# 1622      PAY/SALARY   4413.74  2280.36
# 1785      INTER BANK   4392.74    21.00
# 1862             POS   4184.19   208.55
# 1866       SALES-POS   4162.11    22.08
# 1896             POS   4144.69    17.42
# ...

# %%
df[df['txn_description']== 'PAYMENT']
# Out:
#        status  card_present_flag bpay_biller_code         account currency  \
# 5      posted                NaN              NaN  ACC-1608363396      AUD
# 10     posted                NaN              NaN  ACC-2171593283      AUD
# 11     posted                NaN              NaN  ACC-2776252858      AUD
# 17     posted                NaN              NaN  ACC-4163822186      AUD
# 18     posted                NaN              NaN  ACC-3954677887      AUD
# ...       ...                ...              ...             ...      ...
# 12021  posted                NaN              NaN  ACC-1650504218      AUD
# 12032  posted                NaN              NaN  ACC-1710017148      AUD
# 12035  posted                NaN              NaN  ACC-1973887809      AUD
# 12036  posted                NaN              NaN  ACC-1349834573      AUD
# 12037  posted                NaN              NaN   ACC-240804743      AUD
#
# ...

# %%
df.loc[df['customer_id'] == 'CUS-1005756958'].head()
# Out:
#          status  card_present_flag bpay_biller_code         account currency  \
# 163  authorized                1.0              NaN  ACC-2828321672      AUD
# 272  authorized                1.0              NaN  ACC-2828321672      AUD
# 315  authorized                1.0              NaN  ACC-2828321672      AUD
# 320  authorized                0.0              NaN  ACC-2828321672      AUD
# 435  authorized                1.0              NaN  ACC-2828321672      AUD
#
#           long_lat txn_description                           merchant_id  \
# 163  153.03 -27.51             POS  0a1d930e-fed4-4d23-adee-6f46a9ac8bdb
# 272  153.03 -27.51       SALES-POS  9bd98735-8b39-4eb1-9226-4624430f74a1
# 315  153.03 -27.51             POS  392af96c-2a99-45eb-94e8-cddef88e1331
# 320  153.03 -27.51             POS  cd62798b-8895-4037-99f7-50c70d39abe0
# 435  153.03 -27.51       SALES-POS  9533e9e6-f9ea-49b8-b618-c11146028ba5
#
# ...

# %%
pd.pivot_table(df,index=['age']).mean()
# Out:
# amount                 208.817010
# balance              18123.961786
# card_present_flag        0.805853
# lat                    -38.595808
# long                   143.246540
# merchant_code            0.000000
# merchant_lat           -33.602575
# merchant_long          143.333795
# dtype: float64

# %%
df.groupby(['date', 'txn_description']).size().unstack().plot.barh(stacked=True, figsize=(20,50))
# Out:
# <AxesSubplot:ylabel='date'>

# %%
df.set_index(['date'])
# Out:
#                 status  card_present_flag bpay_biller_code         account  \
# date
# 2018-08-01  authorized                1.0              NaN  ACC-1598451071
# 2018-08-01  authorized                0.0              NaN  ACC-1598451071
# 2018-08-01  authorized                1.0              NaN  ACC-1222300524
# 2018-08-01  authorized                1.0              NaN  ACC-1037050564
# 2018-08-01  authorized                1.0              NaN  ACC-1598451071
# ...                ...                ...              ...             ...
# 2018-10-31  authorized                0.0              NaN  ACC-3021093232
# 2018-10-31  authorized                1.0              NaN  ACC-1608363396
# 2018-10-31  authorized                1.0              NaN  ACC-3827517394
# 2018-10-31  authorized                1.0              NaN  ACC-2920611728
# 2018-10-31  authorized                1.0              NaN  ACC-1443681913
#
#            currency       long_lat txn_description  \
# date
# ...
